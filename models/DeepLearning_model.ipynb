# %%
# Update sklearn to prevent version mismatches
#!pip install sklearn --upgrade  !! This has been done
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\gshre\anaconda3\lib\site-packages (from sklearn) (0.22.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\gshre\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\gshre\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\gshre\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.1)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1320 sha256=c3e40cfb58143f1baca7e5f60af88095fb640fce30c1cc9f3cb6719f57a19329
#   Stored in directory: c:\users\gshre\appdata\local\pip\cache\wheels\46\ef\c3\157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
#!pip install joblib  !! This has been done
# Out:
# Requirement already satisfied: joblib in c:\users\gshre\anaconda3\lib\site-packages (0.14.1)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
print(df.shape)
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
# remove false positive records and other records.....can't do this
#df = df[~(df["koi_disposition"].str.match("CANDIDATE"))]
print(df.shape)
df.head()
# Out:
# (6991, 41)
# (6991, 41)
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.koi_disposition.unique()
# Out:
# array(['CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE'], dtype=object)

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
df['koi_fpflag_nt'] = df['koi_fpflag_nt'].astype('category')
df['koi_fpflag_ss'] = df['koi_fpflag_ss'].astype('category')
df['koi_fpflag_co'] = df['koi_fpflag_co'].astype('category')
df['koi_fpflag_ec'] = df['koi_fpflag_ec'].astype('category')

# %%
# Copy of all features
selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
                        'koi_period', 'koi_period_err1', 'koi_period_err2', 
                        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 
                        'koi_impact', 'koi_impact_err1','koi_impact_err2',
                        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 
                        'koi_depth', 'koi_depth_err1', 'koi_depth_err2',
                        'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 
                        'koi_teq', 
                        'koi_insol',  'koi_insol_err1', 'koi_insol_err2',
                        'koi_model_snr', 
                        'koi_tce_plnt_num',
                        'koi_steff', 'koi_steff_err1', 'koi_steff_err2', 
                        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 
                        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 
                        'ra', 
                        'dec', 
                        'koi_kepmag' 
                       ]]

selected_features.describe()
# Out:
#         koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# count  6991.000000     6.991000e+03     6.991000e+03  6991.000000
# mean     56.191248     1.851122e-03    -1.851122e-03   164.488820
# std     117.570962     7.184503e-03     7.184503e-03    67.020475
# min       0.259820     1.100000e-08    -1.568000e-01   120.515914
# 25%       2.620126     5.005000e-06    -2.401000e-04   132.683917
# 50%       8.947426     3.300000e-05    -3.300000e-05   136.739230
# 75%      34.282605     2.401000e-04    -5.005000e-06   169.937005
# max    1071.232624     1.568000e-01    -1.100000e-08  1472.522306
#
#        koi_time0bk_err1  koi_time0bk_err2   koi_impact  koi_impact_err1  \
# count       6991.000000       6991.000000  6991.000000      6991.000000
# mean           0.009340         -0.009340     0.730631         1.945368
# std            0.021989          0.021989     3.346956         9.401850
# min            0.000009         -0.569000     0.000000         0.000000
# 25%            0.001145         -0.010000     0.198000         0.039900
# 50%            0.003990         -0.003990     0.539000         0.189800
# 75%            0.010000         -0.001145     0.891000         0.379000
# max            0.569000         -0.000009   100.806000        85.540000
#
#        koi_impact_err2  koi_duration  ...  koi_steff_err2    koi_slogg  \
# count      6991.000000   6991.000000  ...     6991.000000  6991.000000
# mean         -0.337243      5.549368  ...     -161.206980     4.305049
# std           1.349036      6.425205  ...       71.448481     0.439238
# min         -59.320000      0.167000  ...    -1733.000000     0.047000
# 25%          -0.446000      2.446000  ...     -197.000000     4.209000
# 50%          -0.204000      3.793000  ...     -159.000000     4.436000
# 75%          -0.044000      6.197500  ...     -112.000000     4.543000
# max           0.000000    138.540000  ...        0.000000     5.364000
#
#        koi_slogg_err1  koi_slogg_err2     koi_srad  koi_srad_err1  \
# count     6991.000000      6991.00000  6991.000000    6991.000000
# mean         0.121091        -0.14048     1.740749       0.352710
# std          0.132048         0.08199     5.903415       0.839017
# min          0.000000        -1.00700     0.109000       0.000000
# 25%          0.044000        -0.19500     0.829000       0.128000
# 50%          0.070000        -0.12700     0.999000       0.248000
# 75%          0.149000        -0.08800     1.357000       0.357000
# max          1.472000         0.00000   180.013000      25.956000
#
#        koi_srad_err2           ra          dec   koi_kepmag
# count    6991.000000  6991.000000  6991.000000  6991.000000
# mean       -0.388568   292.082406    43.812143    14.271508
# std         1.907797     4.762908     3.606167     1.350802
# min      -103.825000   279.856080    36.577381     6.966000
# 25%        -0.252000   288.704730    40.797760    13.455000
# 50%        -0.111000   292.314760    43.679661    14.534000
# 75%        -0.069000   295.888550    46.693659    15.322000
# max         0.000000   301.720760    52.336010    19.065000
#
# [8 rows x 36 columns]

# %% [markdown]
# # Remove err values
# selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
#                         'koi_period',
#                         'koi_time0bk',
#                         'koi_impact',
#                         'koi_duration',
#                         'koi_depth',
#                         'koi_prad',
#                         'koi_teq',
#                         'koi_insol',
#                         'koi_model_snr',
#                         'koi_tce_plnt_num',
#                         'koi_steff',
#                         'koi_slogg',
#                         'koi_srad',
#                         'ra',
#                         'dec',
#                         'koi_kepmag'
#                        ]]
#
# selected_features.describe()

# %%
len(selected_features.columns)
# Out:
# 40

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(selected_features, df["koi_disposition"], random_state=23)

# %%
X_train.head()
# Out:
#      koi_fpflag_nt koi_fpflag_ss koi_fpflag_co koi_fpflag_ec  koi_period  \
# 243              0             0             0             0    5.714624
# 5885             0             1             0             0   27.308150
# 3093             0             0             0             0   91.957230
# 2176             0             0             0             0   31.517795
# 974              0             0             0             0   32.773763
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 243          0.000033        -0.000033   132.638660          0.004320
# 5885         0.000004        -0.000004   143.504361          0.000113
# 3093         0.005680        -0.005680   183.024800          0.065700
# 2176         0.000094        -0.000094   185.153300          0.002230
# 974          0.000179        -0.000179   151.443520          0.004630
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 243          -0.004320  ...             -80      4.365           0.132
# 5885         -0.000113  ...            -163      4.574           0.064
# 3093         -0.065700  ...             -79      4.114           0.182
# 2176         -0.002230  ...             -91      4.144           0.195
# 974          -0.004630  ...             -76      4.076           0.203
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 243           -0.096     1.013          0.141         -0.141  296.06424
# 5885          -0.096     0.739          0.127         -0.068  291.37350
# 3093          -0.098     1.528          0.238         -0.327  289.90417
# 2176          -0.105     1.400          0.211         -0.316  297.27798
# 974           -0.087     1.534          0.240         -0.360  290.88232
#
#             dec  koi_kepmag
# 243   45.976841      15.596
# 5885  51.153381      15.529
# 3093  38.651371      14.876
# 2176  48.320332      12.848
# 974   43.471760      14.758
#
# [5 rows x 40 columns]

# %%
y_train.head()
# Out:
# 243          CONFIRMED
# 5885    FALSE POSITIVE
# 3093         CANDIDATE
# 2176         CONFIRMED
# 974          CANDIDATE
# Name: koi_disposition, dtype: object

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
print(X_train_scaled)
# Out:
# [[-0.43181886 -0.57566178 -0.50696421 ...  0.83425283  0.59986111
#    0.97898115]
#  [-0.43181886  1.73713112 -0.50696421 ... -0.15216045  2.02573181
#    0.9294255 ]
#  [-0.43181886 -0.57566178 -0.50696421 ... -0.4611451  -1.41792934
#    0.44644283]
#  ...
#  [-0.43181886 -0.57566178 -0.50696421 ... -1.29672614 -1.29486717
#    0.25857514]
#  [-0.43181886  1.73713112  1.97252584 ...  1.33190079  0.10835338
#   -0.73031895]
#  [ 2.31578584 -0.57566178 -0.50696421 ...  1.15163223  0.39505351
#    0.89836077]]

# %%
# HotKey Encode the data
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
print(encoded_y_train)
# Out:
# [1 2 0 ... 1 2 2]

# %% [markdown]
# # Train the Model

# %%
# first, create a normal neural network with 40 inputs, 3 hidden nodes, and 3 outputs
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=40))
model.add(Dense(units=3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 6)                 246
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 21
# =================================================================
# Total params: 267
# Trainable params: 267
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='SparseCategoricalCrossentropy',
              metrics=['accuracy'])

# %%
model.compile(optimizer='adam',
              loss='SparseCategoricalCrossentropy',
              metrics=['accuracy'])

# %%
# Fit the model to the training data
model.fit(
    X_train_scaled,
    encoded_y_train,
    epochs=200,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/200
# 164/164 - 0s - loss: 1.1003 - accuracy: 0.4568
# Epoch 2/200
# 164/164 - 0s - loss: 0.7755 - accuracy: 0.7257
# Epoch 3/200
# 164/164 - 0s - loss: 0.5543 - accuracy: 0.8032
# Epoch 4/200
# 164/164 - 0s - loss: 0.4422 - accuracy: 0.8365
# Epoch 5/200
# 164/164 - 0s - loss: 0.3830 - accuracy: 0.8535
# Epoch 6/200
# 164/164 - 0s - loss: 0.3488 - accuracy: 0.8611
# Epoch 7/200
# 164/164 - 0s - loss: 0.3276 - accuracy: 0.8671
# Epoch 8/200
# 164/164 - 0s - loss: 0.3135 - accuracy: 0.8709
# Epoch 9/200
# 164/164 - 0s - loss: 0.3032 - accuracy: 0.8737
# Epoch 10/200
# 164/164 - 0s - loss: 0.2963 - accuracy: 0.8764
# Epoch 11/200
# 164/164 - 0s - loss: 0.2902 - accuracy: 0.8787
# Epoch 12/200
# 164/164 - 0s - loss: 0.2857 - accuracy: 0.8791
# Epoch 13/200
# 164/164 - 0s - loss: 0.2825 - accuracy: 0.8800
# Epoch 14/200
# 164/164 - 0s - loss: 0.2798 - accuracy: 0.8798
# Epoch 15/200
# 164/164 - 0s - loss: 0.2765 - accuracy: 0.8831
# Epoch 16/200
# 164/164 - 0s - loss: 0.2746 - accuracy: 0.8835
# Epoch 17/200
# 164/164 - 0s - loss: 0.2725 - accuracy: 0.8821
# Epoch 18/200
# 164/164 - 0s - loss: 0.2714 - accuracy: 0.8848
# Epoch 19/200
# 164/164 - 0s - loss: 0.2695 - accuracy: 0.8863
# Epoch 20/200
# 164/164 - 0s - loss: 0.2681 - accuracy: 0.8848
# Epoch 21/200
# 164/164 - 0s - loss: 0.2668 - accuracy: 0.8863
# Epoch 22/200
# 164/164 - 0s - loss: 0.2655 - accuracy: 0.8867
# Epoch 23/200
# 164/164 - 0s - loss: 0.2644 - accuracy: 0.8892
# Epoch 24/200
# 164/164 - 0s - loss: 0.2632 - accuracy: 0.8859
# Epoch 25/200
# 164/164 - 0s - loss: 0.2621 - accuracy: 0.8880
# Epoch 26/200
# 164/164 - 0s - loss: 0.2611 - accuracy: 0.8884
# Epoch 27/200
# 164/164 - 0s - loss: 0.2603 - accuracy: 0.8898
# Epoch 28/200
# 164/164 - 0s - loss: 0.2591 - accuracy: 0.8907
# Epoch 29/200
# 164/164 - 0s - loss: 0.2582 - accuracy: 0.8905
# Epoch 30/200
# 164/164 - 0s - loss: 0.2572 - accuracy: 0.8907
# Epoch 31/200
# 164/164 - 0s - loss: 0.2568 - accuracy: 0.8892
# Epoch 32/200
# 164/164 - 0s - loss: 0.2557 - accuracy: 0.8899
# Epoch 33/200
# 164/164 - 0s - loss: 0.2548 - accuracy: 0.8903
# Epoch 34/200
# 164/164 - 0s - loss: 0.2543 - accuracy: 0.8909
# Epoch 35/200
# 164/164 - 0s - loss: 0.2537 - accuracy: 0.8928
# Epoch 36/200
# 164/164 - 0s - loss: 0.2534 - accuracy: 0.8930
# Epoch 37/200
# 164/164 - 0s - loss: 0.2528 - accuracy: 0.8915
# Epoch 38/200
# 164/164 - 0s - loss: 0.2518 - accuracy: 0.8930
# Epoch 39/200
# 164/164 - 0s - loss: 0.2514 - accuracy: 0.8943
# Epoch 40/200
# 164/164 - 0s - loss: 0.2514 - accuracy: 0.8926
# Epoch 41/200
# 164/164 - 0s - loss: 0.2503 - accuracy: 0.8955
# Epoch 42/200
# 164/164 - 0s - loss: 0.2505 - accuracy: 0.8940
# Epoch 43/200
# 164/164 - 0s - loss: 0.2496 - accuracy: 0.8917
# Epoch 44/200
# 164/164 - 0s - loss: 0.2491 - accuracy: 0.8951
# Epoch 45/200
# 164/164 - 0s - loss: 0.2487 - accuracy: 0.8955
# Epoch 46/200
# 164/164 - 0s - loss: 0.2485 - accuracy: 0.8964
# Epoch 47/200
# 164/164 - 0s - loss: 0.2483 - accuracy: 0.8951
# Epoch 48/200
# 164/164 - 0s - loss: 0.2483 - accuracy: 0.8953
# Epoch 49/200
# 164/164 - 0s - loss: 0.2475 - accuracy: 0.8934
# Epoch 50/200
# 164/164 - 0s - loss: 0.2467 - accuracy: 0.8962
# Epoch 51/200
# 164/164 - 0s - loss: 0.2470 - accuracy: 0.8943
# Epoch 52/200
# 164/164 - 0s - loss: 0.2461 - accuracy: 0.8961
# Epoch 53/200
# 164/164 - 0s - loss: 0.2462 - accuracy: 0.8951
# Epoch 54/200
# 164/164 - 0s - loss: 0.2455 - accuracy: 0.8968
# Epoch 55/200
# 164/164 - 0s - loss: 0.2450 - accuracy: 0.8968
# Epoch 56/200
# 164/164 - 0s - loss: 0.2453 - accuracy: 0.8955
# Epoch 57/200
# 164/164 - 0s - loss: 0.2447 - accuracy: 0.8943
# Epoch 58/200
# 164/164 - 0s - loss: 0.2443 - accuracy: 0.8968
# Epoch 59/200
# 164/164 - 0s - loss: 0.2438 - accuracy: 0.8978
# Epoch 60/200
# 164/164 - 0s - loss: 0.2437 - accuracy: 0.8972
# Epoch 61/200
# 164/164 - 0s - loss: 0.2433 - accuracy: 0.8970
# Epoch 62/200
# 164/164 - 0s - loss: 0.2434 - accuracy: 0.8993
# Epoch 63/200
# 164/164 - 0s - loss: 0.2429 - accuracy: 0.8972
# Epoch 64/200
# 164/164 - 0s - loss: 0.2422 - accuracy: 0.8989
# Epoch 65/200
# 164/164 - 0s - loss: 0.2423 - accuracy: 0.8955
# Epoch 66/200
# 164/164 - 0s - loss: 0.2422 - accuracy: 0.8972
# Epoch 67/200
# 164/164 - 0s - loss: 0.2417 - accuracy: 0.8970
# Epoch 68/200
# 164/164 - 0s - loss: 0.2413 - accuracy: 0.8983
# Epoch 69/200
# 164/164 - 0s - loss: 0.2412 - accuracy: 0.8991
# Epoch 70/200
# 164/164 - 0s - loss: 0.2412 - accuracy: 0.8976
# Epoch 71/200
# 164/164 - 0s - loss: 0.2408 - accuracy: 0.8970
# Epoch 72/200
# 164/164 - 0s - loss: 0.2407 - accuracy: 0.8974
# Epoch 73/200
# 164/164 - 0s - loss: 0.2402 - accuracy: 0.8991
# Epoch 74/200
# 164/164 - 0s - loss: 0.2401 - accuracy: 0.8972
# Epoch 75/200
# 164/164 - 0s - loss: 0.2403 - accuracy: 0.8993
# Epoch 76/200
# 164/164 - 0s - loss: 0.2400 - accuracy: 0.8989
# Epoch 77/200
# 164/164 - 0s - loss: 0.2395 - accuracy: 0.8985
# Epoch 78/200
# 164/164 - 0s - loss: 0.2400 - accuracy: 0.8987
# Epoch 79/200
# 164/164 - 0s - loss: 0.2391 - accuracy: 0.8995
# Epoch 80/200
# 164/164 - 0s - loss: 0.2392 - accuracy: 0.9022
# Epoch 81/200
# 164/164 - 0s - loss: 0.2385 - accuracy: 0.8985
# Epoch 82/200
# 164/164 - 0s - loss: 0.2387 - accuracy: 0.9001
# Epoch 83/200
# 164/164 - 0s - loss: 0.2389 - accuracy: 0.8997
# Epoch 84/200
# 164/164 - 0s - loss: 0.2392 - accuracy: 0.8985
# Epoch 85/200
# 164/164 - 0s - loss: 0.2389 - accuracy: 0.8983
# Epoch 86/200
# 164/164 - 0s - loss: 0.2382 - accuracy: 0.8991
# Epoch 87/200
# 164/164 - 0s - loss: 0.2379 - accuracy: 0.8976
# Epoch 88/200
# 164/164 - 0s - loss: 0.2383 - accuracy: 0.8985
# Epoch 89/200
# 164/164 - 0s - loss: 0.2382 - accuracy: 0.8976
# Epoch 90/200
# 164/164 - 0s - loss: 0.2375 - accuracy: 0.9004
# Epoch 91/200
# 164/164 - 0s - loss: 0.2372 - accuracy: 0.9023
# Epoch 92/200
# 164/164 - 0s - loss: 0.2371 - accuracy: 0.8993
# Epoch 93/200
# 164/164 - 0s - loss: 0.2372 - accuracy: 0.9002
# Epoch 94/200
# 164/164 - 0s - loss: 0.2370 - accuracy: 0.8995
# Epoch 95/200
# 164/164 - 0s - loss: 0.2373 - accuracy: 0.8989
# Epoch 96/200
# 164/164 - 0s - loss: 0.2369 - accuracy: 0.9004
# Epoch 97/200
# 164/164 - 0s - loss: 0.2369 - accuracy: 0.8978
# Epoch 98/200
# 164/164 - 0s - loss: 0.2367 - accuracy: 0.9008
# Epoch 99/200
# 164/164 - 0s - loss: 0.2367 - accuracy: 0.8993
# Epoch 100/200
# 164/164 - 0s - loss: 0.2364 - accuracy: 0.8999
# Epoch 101/200
# 164/164 - 0s - loss: 0.2363 - accuracy: 0.8993
# Epoch 102/200
# 164/164 - 0s - loss: 0.2363 - accuracy: 0.9008
# Epoch 103/200
# 164/164 - 0s - loss: 0.2358 - accuracy: 0.9014
# Epoch 104/200
# 164/164 - 0s - loss: 0.2354 - accuracy: 0.9008
# Epoch 105/200
# 164/164 - 0s - loss: 0.2357 - accuracy: 0.9008
# Epoch 106/200
# 164/164 - 0s - loss: 0.2360 - accuracy: 0.9001
# Epoch 107/200
# 164/164 - 0s - loss: 0.2359 - accuracy: 0.8997
# Epoch 108/200
# 164/164 - 0s - loss: 0.2353 - accuracy: 0.9023
# Epoch 109/200
# 164/164 - 0s - loss: 0.2348 - accuracy: 0.9012
# Epoch 110/200
# 164/164 - 0s - loss: 0.2356 - accuracy: 0.8997
# Epoch 111/200
# 164/164 - 0s - loss: 0.2349 - accuracy: 0.8980
# Epoch 112/200
# 164/164 - 0s - loss: 0.2346 - accuracy: 0.9001
# Epoch 113/200
# 164/164 - 0s - loss: 0.2350 - accuracy: 0.8999
# Epoch 114/200
# 164/164 - 0s - loss: 0.2344 - accuracy: 0.9002
# Epoch 115/200
# 164/164 - 0s - loss: 0.2348 - accuracy: 0.9002
# Epoch 116/200
# 164/164 - 0s - loss: 0.2342 - accuracy: 0.8997
# Epoch 117/200
# 164/164 - 0s - loss: 0.2342 - accuracy: 0.8989
# Epoch 118/200
# 164/164 - 0s - loss: 0.2341 - accuracy: 0.8993
# Epoch 119/200
# 164/164 - 0s - loss: 0.2344 - accuracy: 0.8991
# Epoch 120/200
# 164/164 - 0s - loss: 0.2339 - accuracy: 0.9022
# Epoch 121/200
# 164/164 - 0s - loss: 0.2337 - accuracy: 0.8995
# Epoch 122/200
# 164/164 - 0s - loss: 0.2341 - accuracy: 0.9012
# Epoch 123/200
# 164/164 - 0s - loss: 0.2341 - accuracy: 0.9001
# Epoch 124/200
# 164/164 - 0s - loss: 0.2333 - accuracy: 0.9004
# Epoch 125/200
# 164/164 - 0s - loss: 0.2336 - accuracy: 0.9012
# Epoch 126/200
# 164/164 - 0s - loss: 0.2339 - accuracy: 0.8985
# Epoch 127/200
# 164/164 - 0s - loss: 0.2332 - accuracy: 0.8993
# Epoch 128/200
# 164/164 - 0s - loss: 0.2334 - accuracy: 0.9014
# Epoch 129/200
# 164/164 - 0s - loss: 0.2325 - accuracy: 0.8999
# Epoch 130/200
# 164/164 - 0s - loss: 0.2332 - accuracy: 0.8997
# Epoch 131/200
# 164/164 - 0s - loss: 0.2336 - accuracy: 0.8999
# Epoch 132/200
# 164/164 - 0s - loss: 0.2328 - accuracy: 0.9006
# Epoch 133/200
# 164/164 - 0s - loss: 0.2333 - accuracy: 0.9001
# Epoch 134/200
# 164/164 - 0s - loss: 0.2325 - accuracy: 0.8989
# Epoch 135/200
# 164/164 - 0s - loss: 0.2324 - accuracy: 0.8997
# Epoch 136/200
# 164/164 - 0s - loss: 0.2321 - accuracy: 0.8995
# Epoch 137/200
# 164/164 - 0s - loss: 0.2323 - accuracy: 0.8999
# Epoch 138/200
# 164/164 - 0s - loss: 0.2322 - accuracy: 0.8997
# Epoch 139/200
# 164/164 - 0s - loss: 0.2328 - accuracy: 0.9008
# Epoch 140/200
# 164/164 - 0s - loss: 0.2326 - accuracy: 0.8987
# Epoch 141/200
# 164/164 - 0s - loss: 0.2317 - accuracy: 0.9010
# Epoch 142/200
# 164/164 - 0s - loss: 0.2318 - accuracy: 0.8985
# Epoch 143/200
# 164/164 - 0s - loss: 0.2318 - accuracy: 0.8999
# Epoch 144/200
# 164/164 - 0s - loss: 0.2319 - accuracy: 0.8987
# Epoch 145/200
# 164/164 - 0s - loss: 0.2316 - accuracy: 0.8997
# Epoch 146/200
# 164/164 - 0s - loss: 0.2318 - accuracy: 0.8989
# Epoch 147/200
# 164/164 - 0s - loss: 0.2315 - accuracy: 0.9008
# Epoch 148/200
# 164/164 - 0s - loss: 0.2310 - accuracy: 0.9012
# Epoch 149/200
# 164/164 - 0s - loss: 0.2311 - accuracy: 0.8999
# Epoch 150/200
# 164/164 - 0s - loss: 0.2309 - accuracy: 0.8983
# Epoch 151/200
# 164/164 - 0s - loss: 0.2315 - accuracy: 0.9018
# Epoch 152/200
# 164/164 - 0s - loss: 0.2312 - accuracy: 0.8997
# Epoch 153/200
# 164/164 - 0s - loss: 0.2305 - accuracy: 0.9004
# Epoch 154/200
# 164/164 - 0s - loss: 0.2304 - accuracy: 0.9010
# Epoch 155/200
# 164/164 - 0s - loss: 0.2306 - accuracy: 0.8999
# Epoch 156/200
# 164/164 - 0s - loss: 0.2301 - accuracy: 0.9008
# Epoch 157/200
# 164/164 - 0s - loss: 0.2305 - accuracy: 0.8999
# Epoch 158/200
# 164/164 - 0s - loss: 0.2303 - accuracy: 0.8993
# Epoch 159/200
# 164/164 - 0s - loss: 0.2300 - accuracy: 0.9012
# Epoch 160/200
# 164/164 - 0s - loss: 0.2305 - accuracy: 0.8985
# Epoch 161/200
# 164/164 - 0s - loss: 0.2296 - accuracy: 0.9010
# Epoch 162/200
# 164/164 - 0s - loss: 0.2298 - accuracy: 0.9018
# Epoch 163/200
# 164/164 - 0s - loss: 0.2298 - accuracy: 0.9001
# Epoch 164/200
# 164/164 - 0s - loss: 0.2295 - accuracy: 0.9006
# Epoch 165/200
# 164/164 - 0s - loss: 0.2299 - accuracy: 0.9001
# Epoch 166/200
# 164/164 - 0s - loss: 0.2294 - accuracy: 0.9008
# Epoch 167/200
# 164/164 - 0s - loss: 0.2287 - accuracy: 0.9004
# Epoch 168/200
# 164/164 - 0s - loss: 0.2289 - accuracy: 0.9010
# Epoch 169/200
# 164/164 - 0s - loss: 0.2294 - accuracy: 0.9008
# Epoch 170/200
# 164/164 - 0s - loss: 0.2288 - accuracy: 0.9012
# Epoch 171/200
# 164/164 - 0s - loss: 0.2294 - accuracy: 0.9002
# Epoch 172/200
# 164/164 - 0s - loss: 0.2289 - accuracy: 0.9016
# Epoch 173/200
# 164/164 - 0s - loss: 0.2286 - accuracy: 0.9010
# Epoch 174/200
# 164/164 - 0s - loss: 0.2295 - accuracy: 0.8983
# Epoch 175/200
# 164/164 - 0s - loss: 0.2291 - accuracy: 0.9012
# Epoch 176/200
# 164/164 - 0s - loss: 0.2287 - accuracy: 0.9022
# Epoch 177/200
# 164/164 - 0s - loss: 0.2286 - accuracy: 0.9010
# Epoch 178/200
# 164/164 - 0s - loss: 0.2282 - accuracy: 0.9012
# Epoch 179/200
# 164/164 - 0s - loss: 0.2289 - accuracy: 0.9004
# Epoch 180/200
# 164/164 - 0s - loss: 0.2287 - accuracy: 0.9001
# Epoch 181/200
# 164/164 - 0s - loss: 0.2286 - accuracy: 0.8999
# Epoch 182/200
# 164/164 - 0s - loss: 0.2285 - accuracy: 0.9025
# Epoch 183/200
# 164/164 - 0s - loss: 0.2281 - accuracy: 0.9012
# Epoch 184/200
# 164/164 - 0s - loss: 0.2278 - accuracy: 0.9012
# Epoch 185/200
# 164/164 - 0s - loss: 0.2282 - accuracy: 0.9012
# Epoch 186/200
# 164/164 - 0s - loss: 0.2281 - accuracy: 0.9018
# Epoch 187/200
# 164/164 - 0s - loss: 0.2280 - accuracy: 0.9008
# Epoch 188/200
# 164/164 - 0s - loss: 0.2278 - accuracy: 0.9002
# Epoch 189/200
# 164/164 - 0s - loss: 0.2282 - accuracy: 0.9014
# Epoch 190/200
# 164/164 - 0s - loss: 0.2274 - accuracy: 0.8991
# Epoch 191/200
# 164/164 - 0s - loss: 0.2272 - accuracy: 0.9029
# Epoch 192/200
# 164/164 - 0s - loss: 0.2276 - accuracy: 0.9001
# Epoch 193/200
# 164/164 - 0s - loss: 0.2273 - accuracy: 0.9018
# Epoch 194/200
# 164/164 - 0s - loss: 0.2275 - accuracy: 0.9004
# Epoch 195/200
# 164/164 - 0s - loss: 0.2272 - accuracy: 0.9018
# Epoch 196/200
# 164/164 - 0s - loss: 0.2272 - accuracy: 0.9025
# Epoch 197/200
# 164/164 - 0s - loss: 0.2273 - accuracy: 0.9018
# Epoch 198/200
# 164/164 - 0s - loss: 0.2273 - accuracy: 0.9004
# Epoch 199/200
# 164/164 - 0s - loss: 0.2270 - accuracy: 0.9012
# Epoch 200/200
# 164/164 - 0s - loss: 0.2270 - accuracy: 0.9012

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, encoded_y_test, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.3999 - accuracy: 0.9005
# Normal Neural Network - Loss: 0.3999023139476776, Accuracy: 0.9004576802253723

# %% [markdown]
# # Hyperparameter Tuning
#
# Not available in this case

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'deep_learning_model.sav'
joblib.dump(model, filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-8a5d0039d89b> in <module>
#       5 import joblib
#       6 filename = 'deep_learning_model.sav'
# ----> 7 joblib.dump(model, filename)
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     503     elif is_filename:
#     504         with open(filename, 'wb') as f:
# --> 505             NumpyPickler(f, protocol=protocol).dump(value)
#     506     else:
#     507         NumpyPickler(filename, protocol=protocol).dump(value)
#
# ~\Anaconda3\lib\pickle.py in dump(self, obj)
#     435         if self.proto >= 4:
#     436             self.framer.start_framing()
# --> 437         self.save(obj)
#     438         self.write(STOP)
#     439         self.framer.end_framing()
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# ~\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# ~\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# ~\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# ~\Anaconda3\lib\pickle.py in save_list(self, obj)
#     817
#     818         self.memoize(obj)
# --> 819         self._batch_appends(obj)
#     820
#     821     dispatch[list] = save_list
#
# ~\Anaconda3\lib\pickle.py in _batch_appends(self, items)
#     841                 write(MARK)
#     842                 for x in tmp:
# --> 843                     save(x)
#     844                 write(APPENDS)
#     845             elif n:
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# ~\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# ~\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# ~\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# ~\Anaconda3\lib\pickle.py in save_list(self, obj)
#     817
#     818         self.memoize(obj)
# --> 819         self._batch_appends(obj)
#     820
#     821     dispatch[list] = save_list
#
# ~\Anaconda3\lib\pickle.py in _batch_appends(self, items)
#     844                 write(APPENDS)
#     845             elif n:
# --> 846                 save(tmp[0])
#     847                 write(APPEND)
#     848             # else tmp is empty, and we're done
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# ~\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# ~\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# ~\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# ~\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# ~\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# ~\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# ~\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# ~\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# ~\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# ~\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# ~\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# ~\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     293             return
#     294
# --> 295         return Pickler.save(self, obj)
#     296
#     297
#
# ~\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     522             reduce = getattr(obj, "__reduce_ex__", None)
#     523             if reduce is not None:
# --> 524                 rv = reduce(self.proto)
#     525             else:
#     526                 reduce = getattr(obj, "__reduce__", None)
#
# TypeError: can't pickle _thread.RLock objects
