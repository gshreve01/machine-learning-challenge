# %%
# Update sklearn to prevent version mismatches
#!pip install sklearn --upgrade  !! This has been done
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\gshre\anaconda3\lib\site-packages (from sklearn) (0.22.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\gshre\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\gshre\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\gshre\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.1)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1320 sha256=c3e40cfb58143f1baca7e5f60af88095fb640fce30c1cc9f3cb6719f57a19329
#   Stored in directory: c:\users\gshre\appdata\local\pip\cache\wheels\46\ef\c3\157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
#!pip install joblib  !! This has been done
# Out:
# Requirement already satisfied: joblib in c:\users\gshre\anaconda3\lib\site-packages (0.14.1)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
print(df.shape)
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
# remove false positive records and other records.....can't do this
#df = df[~(df["koi_disposition"].str.match("CANDIDATE"))]
print(df.shape)
df.head()
# Out:
# (6991, 41)
# (6991, 41)
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.koi_disposition.unique()
# Out:
# array(['CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE'], dtype=object)

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
df['koi_fpflag_nt'] = df['koi_fpflag_nt'].astype('category')
df['koi_fpflag_ss'] = df['koi_fpflag_ss'].astype('category')
df['koi_fpflag_co'] = df['koi_fpflag_co'].astype('category')
df['koi_fpflag_ec'] = df['koi_fpflag_ec'].astype('category')

# %%
# Copy of all features
selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
                        'koi_period', 'koi_period_err1', 'koi_period_err2', 
                        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 
                        'koi_impact', 'koi_impact_err1','koi_impact_err2',
                        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 
                        'koi_depth', 'koi_depth_err1', 'koi_depth_err2',
                        'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 
                        'koi_teq', 
                        'koi_insol',  'koi_insol_err1', 'koi_insol_err2',
                        'koi_model_snr', 
                        'koi_tce_plnt_num',
                        'koi_steff', 'koi_steff_err1', 'koi_steff_err2', 
                        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 
                        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 
                        'ra', 
                        'dec', 
                        'koi_kepmag' 
                       ]]

selected_features.describe()
# Out:
#         koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# count  6991.000000     6.991000e+03     6.991000e+03  6991.000000
# mean     56.191248     1.851122e-03    -1.851122e-03   164.488820
# std     117.570962     7.184503e-03     7.184503e-03    67.020475
# min       0.259820     1.100000e-08    -1.568000e-01   120.515914
# 25%       2.620126     5.005000e-06    -2.401000e-04   132.683917
# 50%       8.947426     3.300000e-05    -3.300000e-05   136.739230
# 75%      34.282605     2.401000e-04    -5.005000e-06   169.937005
# max    1071.232624     1.568000e-01    -1.100000e-08  1472.522306
#
#        koi_time0bk_err1  koi_time0bk_err2   koi_impact  koi_impact_err1  \
# count       6991.000000       6991.000000  6991.000000      6991.000000
# mean           0.009340         -0.009340     0.730631         1.945368
# std            0.021989          0.021989     3.346956         9.401850
# min            0.000009         -0.569000     0.000000         0.000000
# 25%            0.001145         -0.010000     0.198000         0.039900
# 50%            0.003990         -0.003990     0.539000         0.189800
# 75%            0.010000         -0.001145     0.891000         0.379000
# max            0.569000         -0.000009   100.806000        85.540000
#
#        koi_impact_err2  koi_duration  ...  koi_steff_err2    koi_slogg  \
# count      6991.000000   6991.000000  ...     6991.000000  6991.000000
# mean         -0.337243      5.549368  ...     -161.206980     4.305049
# std           1.349036      6.425205  ...       71.448481     0.439238
# min         -59.320000      0.167000  ...    -1733.000000     0.047000
# 25%          -0.446000      2.446000  ...     -197.000000     4.209000
# 50%          -0.204000      3.793000  ...     -159.000000     4.436000
# 75%          -0.044000      6.197500  ...     -112.000000     4.543000
# max           0.000000    138.540000  ...        0.000000     5.364000
#
#        koi_slogg_err1  koi_slogg_err2     koi_srad  koi_srad_err1  \
# count     6991.000000      6991.00000  6991.000000    6991.000000
# mean         0.121091        -0.14048     1.740749       0.352710
# std          0.132048         0.08199     5.903415       0.839017
# min          0.000000        -1.00700     0.109000       0.000000
# 25%          0.044000        -0.19500     0.829000       0.128000
# 50%          0.070000        -0.12700     0.999000       0.248000
# 75%          0.149000        -0.08800     1.357000       0.357000
# max          1.472000         0.00000   180.013000      25.956000
#
#        koi_srad_err2           ra          dec   koi_kepmag
# count    6991.000000  6991.000000  6991.000000  6991.000000
# mean       -0.388568   292.082406    43.812143    14.271508
# std         1.907797     4.762908     3.606167     1.350802
# min      -103.825000   279.856080    36.577381     6.966000
# 25%        -0.252000   288.704730    40.797760    13.455000
# 50%        -0.111000   292.314760    43.679661    14.534000
# 75%        -0.069000   295.888550    46.693659    15.322000
# max         0.000000   301.720760    52.336010    19.065000
#
# [8 rows x 36 columns]

# %% [markdown]
# # Remove err values
# selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
#                         'koi_period',
#                         'koi_time0bk',
#                         'koi_impact',
#                         'koi_duration',
#                         'koi_depth',
#                         'koi_prad',
#                         'koi_teq',
#                         'koi_insol',
#                         'koi_model_snr',
#                         'koi_tce_plnt_num',
#                         'koi_steff',
#                         'koi_slogg',
#                         'koi_srad',
#                         'ra',
#                         'dec',
#                         'koi_kepmag'
#                        ]]
#
# selected_features.describe()

# %%
len(selected_features.columns)
# Out:
# 40

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(selected_features, df["koi_disposition"], random_state=23)

# %%
X_train.head()
# Out:
#      koi_fpflag_nt koi_fpflag_ss koi_fpflag_co koi_fpflag_ec  koi_period  \
# 243              0             0             0             0    5.714624
# 5885             0             1             0             0   27.308150
# 3093             0             0             0             0   91.957230
# 2176             0             0             0             0   31.517795
# 974              0             0             0             0   32.773763
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 243          0.000033        -0.000033   132.638660          0.004320
# 5885         0.000004        -0.000004   143.504361          0.000113
# 3093         0.005680        -0.005680   183.024800          0.065700
# 2176         0.000094        -0.000094   185.153300          0.002230
# 974          0.000179        -0.000179   151.443520          0.004630
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 243          -0.004320  ...             -80      4.365           0.132
# 5885         -0.000113  ...            -163      4.574           0.064
# 3093         -0.065700  ...             -79      4.114           0.182
# 2176         -0.002230  ...             -91      4.144           0.195
# 974          -0.004630  ...             -76      4.076           0.203
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 243           -0.096     1.013          0.141         -0.141  296.06424
# 5885          -0.096     0.739          0.127         -0.068  291.37350
# 3093          -0.098     1.528          0.238         -0.327  289.90417
# 2176          -0.105     1.400          0.211         -0.316  297.27798
# 974           -0.087     1.534          0.240         -0.360  290.88232
#
#             dec  koi_kepmag
# 243   45.976841      15.596
# 5885  51.153381      15.529
# 3093  38.651371      14.876
# 2176  48.320332      12.848
# 974   43.471760      14.758
#
# [5 rows x 40 columns]

# %%
y_train.head()
# Out:
# 243          CONFIRMED
# 5885    FALSE POSITIVE
# 3093         CANDIDATE
# 2176         CONFIRMED
# 974          CANDIDATE
# Name: koi_disposition, dtype: object

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
print(X_train_scaled)
# Out:
# [[-0.43181886 -0.57566178 -0.50696421 ...  0.83425283  0.59986111
#    0.97898115]
#  [-0.43181886  1.73713112 -0.50696421 ... -0.15216045  2.02573181
#    0.9294255 ]
#  [-0.43181886 -0.57566178 -0.50696421 ... -0.4611451  -1.41792934
#    0.44644283]
#  ...
#  [-0.43181886 -0.57566178 -0.50696421 ... -1.29672614 -1.29486717
#    0.25857514]
#  [-0.43181886  1.73713112  1.97252584 ...  1.33190079  0.10835338
#   -0.73031895]
#  [ 2.31578584 -0.57566178 -0.50696421 ...  1.15163223  0.39505351
#    0.89836077]]

# %%
# HotKey Encode the data
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
print(encoded_y_train)
# Out:
# [1 2 0 ... 1 2 2]

# %% [markdown]
# # Train the Model

# %%
# first, create a normal neural network with 40 inputs, 3 hidden nodes, and 3 outputs
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=40))
model.add(Dense(units=3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 6)                 246
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 21
# =================================================================
# Total params: 267
# Trainable params: 267
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='SparseCategoricalCrossentropy',
              metrics=['accuracy'])

# %%
model.compile(optimizer='adam',
              loss='SparseCategoricalCrossentropy',
              metrics=['accuracy'])

# %%
# Fit the model to the training data
model.fit(
    X_train_scaled,
    encoded_y_train,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 1.0188 - accuracy: 0.7038
# Epoch 2/100
# 164/164 - 0s - loss: 0.8349 - accuracy: 0.7385
# Epoch 3/100
# 164/164 - 0s - loss: 0.5744 - accuracy: 0.7831
# Epoch 4/100
# 164/164 - 0s - loss: 0.4712 - accuracy: 0.8152
# Epoch 5/100
# 164/164 - 0s - loss: 0.4118 - accuracy: 0.8375
# Epoch 6/100
# 164/164 - 0s - loss: 0.3730 - accuracy: 0.8472
# Epoch 7/100
# 164/164 - 0s - loss: 0.3479 - accuracy: 0.8516
# Epoch 8/100
# 164/164 - 0s - loss: 0.3311 - accuracy: 0.8558
# Epoch 9/100
# 164/164 - 0s - loss: 0.3182 - accuracy: 0.8621
# Epoch 10/100
# 164/164 - 0s - loss: 0.3085 - accuracy: 0.8669
# Epoch 11/100
# 164/164 - 0s - loss: 0.3016 - accuracy: 0.8695
# Epoch 12/100
# 164/164 - 0s - loss: 0.2959 - accuracy: 0.8737
# Epoch 13/100
# 164/164 - 0s - loss: 0.2911 - accuracy: 0.8743
# Epoch 14/100
# 164/164 - 0s - loss: 0.2873 - accuracy: 0.8756
# Epoch 15/100
# 164/164 - 0s - loss: 0.2838 - accuracy: 0.8798
# Epoch 16/100
# 164/164 - 0s - loss: 0.2810 - accuracy: 0.8833
# Epoch 17/100
# 164/164 - 0s - loss: 0.2784 - accuracy: 0.8812
# Epoch 18/100
# 164/164 - 0s - loss: 0.2761 - accuracy: 0.8844
# Epoch 19/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8852
# Epoch 20/100
# 164/164 - 0s - loss: 0.2719 - accuracy: 0.8859
# Epoch 21/100
# 164/164 - 0s - loss: 0.2707 - accuracy: 0.8867
# Epoch 22/100
# 164/164 - 0s - loss: 0.2689 - accuracy: 0.8877
# Epoch 23/100
# 164/164 - 0s - loss: 0.2677 - accuracy: 0.8884
# Epoch 24/100
# 164/164 - 0s - loss: 0.2661 - accuracy: 0.8884
# Epoch 25/100
# 164/164 - 0s - loss: 0.2649 - accuracy: 0.8886
# Epoch 26/100
# 164/164 - 0s - loss: 0.2639 - accuracy: 0.8886
# Epoch 27/100
# 164/164 - 0s - loss: 0.2627 - accuracy: 0.8898
# Epoch 28/100
# 164/164 - 0s - loss: 0.2615 - accuracy: 0.8898
# Epoch 29/100
# 164/164 - 0s - loss: 0.2601 - accuracy: 0.8930
# Epoch 30/100
# 164/164 - 0s - loss: 0.2597 - accuracy: 0.8919
# Epoch 31/100
# 164/164 - 0s - loss: 0.2586 - accuracy: 0.8928
# Epoch 32/100
# 164/164 - 0s - loss: 0.2579 - accuracy: 0.8911
# Epoch 33/100
# 164/164 - 0s - loss: 0.2568 - accuracy: 0.8945
# Epoch 34/100
# 164/164 - 0s - loss: 0.2563 - accuracy: 0.8915
# Epoch 35/100
# 164/164 - 0s - loss: 0.2551 - accuracy: 0.8938
# Epoch 36/100
# 164/164 - 0s - loss: 0.2547 - accuracy: 0.8947
# Epoch 37/100
# 164/164 - 0s - loss: 0.2538 - accuracy: 0.8945
# Epoch 38/100
# 164/164 - 0s - loss: 0.2534 - accuracy: 0.8961
# Epoch 39/100
# 164/164 - 0s - loss: 0.2526 - accuracy: 0.8953
# Epoch 40/100
# 164/164 - 0s - loss: 0.2525 - accuracy: 0.8940
# Epoch 41/100
# 164/164 - 0s - loss: 0.2514 - accuracy: 0.8962
# Epoch 42/100
# 164/164 - 0s - loss: 0.2509 - accuracy: 0.8961
# Epoch 43/100
# 164/164 - 0s - loss: 0.2503 - accuracy: 0.8961
# Epoch 44/100
# 164/164 - 0s - loss: 0.2501 - accuracy: 0.8955
# Epoch 45/100
# 164/164 - 0s - loss: 0.2492 - accuracy: 0.8961
# Epoch 46/100
# 164/164 - 0s - loss: 0.2486 - accuracy: 0.8953
# Epoch 47/100
# 164/164 - 0s - loss: 0.2486 - accuracy: 0.8962
# Epoch 48/100
# 164/164 - 0s - loss: 0.2481 - accuracy: 0.8955
# Epoch 49/100
# 164/164 - 0s - loss: 0.2474 - accuracy: 0.8985
# Epoch 50/100
# 164/164 - 0s - loss: 0.2467 - accuracy: 0.8955
# Epoch 51/100
# 164/164 - 0s - loss: 0.2472 - accuracy: 0.8978
# Epoch 52/100
# 164/164 - 0s - loss: 0.2460 - accuracy: 0.8972
# Epoch 53/100
# 164/164 - 0s - loss: 0.2465 - accuracy: 0.8987
# Epoch 54/100
# 164/164 - 0s - loss: 0.2457 - accuracy: 0.8980
# Epoch 55/100
# 164/164 - 0s - loss: 0.2447 - accuracy: 0.8972
# Epoch 56/100
# 164/164 - 0s - loss: 0.2449 - accuracy: 0.8981
# Epoch 57/100
# 164/164 - 0s - loss: 0.2445 - accuracy: 0.8976
# Epoch 58/100
# 164/164 - 0s - loss: 0.2442 - accuracy: 0.8983
# Epoch 59/100
# 164/164 - 0s - loss: 0.2438 - accuracy: 0.8991
# Epoch 60/100
# 164/164 - 0s - loss: 0.2440 - accuracy: 0.8972
# Epoch 61/100
# 164/164 - 0s - loss: 0.2435 - accuracy: 0.8985
# Epoch 62/100
# 164/164 - 0s - loss: 0.2432 - accuracy: 0.8995
# Epoch 63/100
# 164/164 - 0s - loss: 0.2429 - accuracy: 0.8974
# Epoch 64/100
# 164/164 - 0s - loss: 0.2425 - accuracy: 0.8978
# Epoch 65/100
# 164/164 - 0s - loss: 0.2423 - accuracy: 0.8980
# Epoch 66/100
# 164/164 - 0s - loss: 0.2425 - accuracy: 0.8989
# Epoch 67/100
# 164/164 - 0s - loss: 0.2422 - accuracy: 0.8972
# Epoch 68/100
# 164/164 - 0s - loss: 0.2418 - accuracy: 0.8974
# Epoch 69/100
# 164/164 - 0s - loss: 0.2414 - accuracy: 0.8987
# Epoch 70/100
# 164/164 - 0s - loss: 0.2419 - accuracy: 0.8999
# Epoch 71/100
# 164/164 - 0s - loss: 0.2412 - accuracy: 0.8995
# Epoch 72/100
# 164/164 - 0s - loss: 0.2413 - accuracy: 0.8983
# Epoch 73/100
# 164/164 - 0s - loss: 0.2411 - accuracy: 0.8999
# Epoch 74/100
# 164/164 - 0s - loss: 0.2405 - accuracy: 0.8980
# Epoch 75/100
# 164/164 - 0s - loss: 0.2407 - accuracy: 0.8978
# Epoch 76/100
# 164/164 - 0s - loss: 0.2406 - accuracy: 0.8991
# Epoch 77/100
# 164/164 - 0s - loss: 0.2399 - accuracy: 0.8993
# Epoch 78/100
# 164/164 - 0s - loss: 0.2401 - accuracy: 0.8980
# Epoch 79/100
# 164/164 - 0s - loss: 0.2398 - accuracy: 0.8987
# Epoch 80/100
# 164/164 - 0s - loss: 0.2400 - accuracy: 0.8993
# Epoch 81/100
# 164/164 - 0s - loss: 0.2393 - accuracy: 0.8999
# Epoch 82/100
# 164/164 - 0s - loss: 0.2394 - accuracy: 0.8997
# Epoch 83/100
# 164/164 - 0s - loss: 0.2393 - accuracy: 0.8997
# Epoch 84/100
# 164/164 - 0s - loss: 0.2391 - accuracy: 0.8993
# Epoch 85/100
# 164/164 - 0s - loss: 0.2388 - accuracy: 0.8999
# Epoch 86/100
# 164/164 - 0s - loss: 0.2386 - accuracy: 0.8993
# Epoch 87/100
# 164/164 - 0s - loss: 0.2385 - accuracy: 0.9001
# Epoch 88/100
# 164/164 - 0s - loss: 0.2383 - accuracy: 0.8995
# Epoch 89/100
# 164/164 - 0s - loss: 0.2382 - accuracy: 0.8991
# Epoch 90/100
# 164/164 - 0s - loss: 0.2381 - accuracy: 0.8985
# Epoch 91/100
# 164/164 - 0s - loss: 0.2377 - accuracy: 0.9001
# Epoch 92/100
# 164/164 - 0s - loss: 0.2381 - accuracy: 0.8989
# Epoch 93/100
# 164/164 - 0s - loss: 0.2372 - accuracy: 0.8993
# Epoch 94/100
# 164/164 - 0s - loss: 0.2375 - accuracy: 0.8993
# Epoch 95/100
# 164/164 - 0s - loss: 0.2377 - accuracy: 0.8989
# Epoch 96/100
# 164/164 - 0s - loss: 0.2374 - accuracy: 0.8989
# Epoch 97/100
# 164/164 - 0s - loss: 0.2370 - accuracy: 0.8997
# Epoch 98/100
# 164/164 - 0s - loss: 0.2372 - accuracy: 0.8997
# Epoch 99/100
# 164/164 - 0s - loss: 0.2367 - accuracy: 0.9001
# Epoch 100/100
# 164/164 - 0s - loss: 0.2371 - accuracy: 0.9008

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, encoded_y_test, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2785 - accuracy: 0.9010
# Normal Neural Network - Loss: 0.2785016894340515, Accuracy: 0.9010297656059265

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [1, 5, 10],
              'max_iter': [1000],
              'n_jobs': [1, 2, 3]}
grid = GridSearchCV(model, param_grid, verbose=3)
print(grid.estimator.get_params().keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-559b16ed8f0f> in <module>
#       6               'n_jobs': [1, 2, 3]}
#       7 grid = GridSearchCV(model, param_grid, verbose=3)
# ----> 8 print(grid.estimator.get_params().keys())
#
# AttributeError: 'Sequential' object has no attribute 'get_params'

# %% [markdown]
# # Create the GridSearchCV model
# from sklearn.model_selection import GridSearchCV
#
# param_grid = {'C': [1, 5, 10, 50],
#               'kernel': ['linear'],
#               'gamma': [0.0001, 0.0005, 0.001, 0.005]}
# grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, encoded_y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, max_iter=1000, n_jobs=1 ....................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ........ C=1, max_iter=1000, n_jobs=1, score=0.860, total=   0.3s
# [CV] C=1, max_iter=1000, n_jobs=1 ....................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ........ C=1, max_iter=1000, n_jobs=1, score=0.832, total=   0.3s
# [CV] C=1, max_iter=1000, n_jobs=1 ....................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV] ........ C=1, max_iter=1000, n_jobs=1, score=0.845, total=   0.3s
# [CV] C=1, max_iter=1000, n_jobs=1 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=1, score=0.826, total=   0.2s
# [CV] C=1, max_iter=1000, n_jobs=1 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=1, score=0.851, total=   0.3s
# [CV] C=1, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=2, score=0.860, total=   1.0s
# [CV] C=1, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=2, score=0.832, total=   0.8s
# [CV] C=1, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=2, score=0.845, total=   0.6s
# [CV] C=1, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=2, score=0.826, total=   0.6s
# [CV] C=1, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=2, score=0.851, total=   0.6s
# [CV] C=1, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=3, score=0.860, total=   1.0s
# [CV] C=1, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=3, score=0.832, total=   0.7s
# [CV] C=1, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=3, score=0.845, total=   0.8s
# [CV] C=1, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=3, score=0.826, total=   0.5s
# [CV] C=1, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=1, max_iter=1000, n_jobs=3, score=0.851, total=   0.6s
# [CV] C=5, max_iter=1000, n_jobs=1 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=1, score=0.865, total=   0.6s
# [CV] C=5, max_iter=1000, n_jobs=1 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=1, score=0.864, total=   0.6s
# [CV] C=5, max_iter=1000, n_jobs=1 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=1, score=0.867, total=   0.5s
# [CV] C=5, max_iter=1000, n_jobs=1 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=1, score=0.841, total=   0.5s
# [CV] C=5, max_iter=1000, n_jobs=1 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=1, score=0.865, total=   0.5s
# [CV] C=5, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=2, score=0.865, total=   1.6s
# [CV] C=5, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=2, score=0.864, total=   1.4s
# [CV] C=5, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=2, score=0.867, total=   1.1s
# [CV] C=5, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=2, score=0.841, total=   1.2s
# [CV] C=5, max_iter=1000, n_jobs=2 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=2, score=0.865, total=   1.1s
# [CV] C=5, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=3, score=0.865, total=   1.4s
# [CV] C=5, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=3, score=0.864, total=   1.3s
# [CV] C=5, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=3, score=0.867, total=   1.3s
# [CV] C=5, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=3, score=0.842, total=   1.1s
# [CV] C=5, max_iter=1000, n_jobs=3 ....................................
# [CV] ........ C=5, max_iter=1000, n_jobs=3, score=0.865, total=   1.1s
# [CV] C=10, max_iter=1000, n_jobs=1 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=1, score=0.872, total=   0.8s
# [CV] C=10, max_iter=1000, n_jobs=1 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=1, score=0.866, total=   0.7s
# [CV] C=10, max_iter=1000, n_jobs=1 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=1, score=0.874, total=   0.7s
# [CV] C=10, max_iter=1000, n_jobs=1 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=1, score=0.851, total=   0.7s
# [CV] C=10, max_iter=1000, n_jobs=1 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=1, score=0.872, total=   0.9s
# [CV] C=10, max_iter=1000, n_jobs=2 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=2, score=0.872, total=   1.9s
# [CV] C=10, max_iter=1000, n_jobs=2 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=2, score=0.866, total=   1.7s
# [CV] C=10, max_iter=1000, n_jobs=2 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=2, score=0.874, total=   1.4s
# [CV] C=10, max_iter=1000, n_jobs=2 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=2, score=0.851, total=   1.6s
# [CV] C=10, max_iter=1000, n_jobs=2 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=2, score=0.872, total=   1.8s
# [CV] C=10, max_iter=1000, n_jobs=3 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=3, score=0.872, total=   1.9s
# [CV] C=10, max_iter=1000, n_jobs=3 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=3, score=0.865, total=   1.7s
# [CV] C=10, max_iter=1000, n_jobs=3 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=3, score=0.874, total=   1.4s
# [CV] C=10, max_iter=1000, n_jobs=3 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=3, score=0.851, total=   1.5s
# [CV] C=10, max_iter=1000, n_jobs=3 ...................................
# [CV] ....... C=10, max_iter=1000, n_jobs=3, score=0.872, total=   1.7s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   44.2s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 5, 10], 'max_iter': [1000],
#                          'n_jobs': [1, 2, 3]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 10, 'max_iter': 1000, 'n_jobs': 1}
# 0.86705877644285

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'logic_regression_model.sav'
joblib.dump(classifier, filename)
# Out:
# ['logic_regression_model.sav']
